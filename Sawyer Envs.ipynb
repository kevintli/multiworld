# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt

from multiworld.envs.mujoco.classic_mujoco.ant_maze import AntMazeEnv
from multiworld.envs.mujoco.classic_mujoco.ant import AntEnv
from multiworld.envs.mujoco import register_mujoco_envs

import gym

# %%
register_mujoco_envs()
env = gym.make('StateSawyerPickAndPlace3DEnv-v0')
# Out:
# Skipping mujoco

# %%
c = env.viewer.cam
c.elevation = -15
c.azimuth = 220
c.distance = 1
c.lookat[0] = 0
c.lookat[1] = 0.5
c.lookat[2] = 0.1
env._set_obj_xyz([0.2, 0.65, 0.02])
# env.step(np.array([5, 5, 10, -1]))

# %%
im = env.render(mode='rgb_array', width=512, height=512)
plt.figure(figsize=(10, 10))
plt.imshow(im)

# %%
env = gym.make('StateSawyerPushForwardEnv-v0')
_ = env.render(mode='rgb_array')

# %%
c = env.viewer.cam
# print(c.elevation)
# print(c.azimuth)
# print(c.distance)
# print(c.lookat[0:3])

c.elevation = -50
c.azimuth = 270
c.distance = 0.3
c.lookat[0] = 0
c.lookat[1] = 0.85
c.lookat[2] = 0.5

env.reset()
# Out:
# array([-0.00705479,  0.52034071,  0.11993855,  0.09266278,  0.6       ])

# %%
im = env.render(mode='rgb_array', width=2048, height=2048)
plt.figure(figsize=(10, 10))
plt.imshow(im)

# %%
env = gym.make('StateSawyerDoorPullHookEnv-v0')
_ = env.render(mode='rgb_array')
# Out:
# Sawyer Door Hook Env: Using reward type angle_success, indicator threshold (0.02, 0.05)

# %%
c = env.viewer.cam
# print(c.elevation)
# print(c.azimuth)
# print(c.distance)
# print(c.lookat[0:3])

c.elevation = -30
c.azimuth = 360
c.distance = 1.5
c.lookat[0] = -0.2
c.lookat[1] = 0.5
c.lookat[2] = 0.3

env.reset()
# Out:
# array([-0.04435759,  0.31614086,  0.400705  ,  0.        ])

# %%
im = env.render(mode='rgb_array', width=2048, height=2048)
plt.figure(figsize=(10, 10))
plt.imshow(im)
